# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavniteenyeole-del/AIML_Experiments/blob/main/AIML_Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                                                     ***Experiment 1***

# %% [markdown]
# *~By Arnav Niteen Yeole (Batch-80) (SAP ID-590029428) (Date-20/01/2026)*

# %% [markdown]
# **Linear Regression**

# %% [markdown]
# **1.Importing Requirerd Libraries and Modules**

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# **2.Dataset** **Loading**

# %%
data=fetch_california_housing(as_frame=True)
df=data.frame

# %% [markdown]
# **3.Feature and Target Selection**

# %%
X=df.drop('MedHouseVal',axis=1)
y=df['MedHouseVal']

# %% [markdown]
# **4.Train Test Split**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# **5.Model Training**

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **6.Model Prediction**

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# **7.Mean** **Squared** **Error**

# %%
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# MSE: 0.5276241065543503

# %% [markdown]
# **8.R2** **Score**

# %%
print("R2Score:",r2_score(y_test,y_pred))
# Out:
# R2Score: 0.5955484871946279

# %% [markdown]
# **9.Plotting**

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %% [markdown]
# **10.Accuracy**

# %%
print("Accuracy:", model.score(X_test, y_test) * 100, "%")
# Out:
# Accuracy: 59.5548487194628 %
